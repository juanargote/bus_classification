# %%
#imports
import pandas as pd
import sqlite3
import pandas.io.sql as sql
import numpy as np

# %%
#make sql connection
connection = sqlite3.connect('predecessor.db')
#import the database as a pandas df
df= sql.read_frame(sql='SELECT trip_id,service_id,bus_id,arrival_time,stop_id,estimated_boardings,dwell_time FROM bus_data', con=connection)

#convert arrival time to a date time object
df['arrival_time'] = pd.to_datetime(df['arrival_time'])

# %%
df.head(5)
# Out:
#                trip_id  service_id  bus_id        arrival_time  stop_id  \
# 0  6110005000215209984         611     485 2013-09-26 13:26:38       46
# 1  6110005000415349760         611     472 2013-09-26 13:40:30       46
# 2  6110005000615409664         611     479 2013-09-26 13:46:58       46
# 3  6110005000915550208         611     486 2013-09-26 13:56:15       46
# 4  6110005000416209920         611     472 2013-09-26 14:22:01       46
#
#    estimated_boardings  dwell_time
# 0                   10          21
# 1                   53         107
# 2                    4           9
# 3                    3           8
# 4                    3           7

# %%
df = df.sort(['stop_id','arrival_time'],ascending= True)
num_rows = len(df.index)
df.index = pd.Series(np.arange(num_rows))

# %%
df.head(20)
# Out:
#                 trip_id  service_id  bus_id        arrival_time  stop_id  \
# 0   6110005001015150592         611     475 2013-09-26 13:38:36       37
# 1   6110005000415349760         611     472 2013-09-26 13:56:49       37
# 2   6110005000615409664         611     479 2013-09-26 14:01:38       37
# 3   6110005000915550208         611     486 2013-09-26 14:12:08       37
# 4   6110025000316199936         611     734 2013-09-26 14:44:00       37
# 5   6110005000616290304         611     479 2013-09-26 14:45:26       37
# 6   6110005000816350208         611     478 2013-09-26 14:55:48       37
# 7   6110005000916410368         611     486 2013-09-26 15:01:42       37
# 8   6110025000416400384         611     737 2013-09-26 15:06:07       37
# 9   6110005001016489984         611     475 2013-09-26 15:06:13       37
# 10  6110025000216999936         611     722 2013-09-26 15:25:49       37
# 11  6110005000417090560         611     472 2013-09-26 15:26:34       37
# 12  6110005000617150464         611     479 2013-09-26 15:37:43       37
# 13  6110005000817210368         611     478 2013-09-26 15:38:52       37
# 14  6110025000317200384         611     734 2013-09-26 15:40:40       37
# 15  6110005000417550336         611     472 2013-09-26 16:14:58       37
# 16  6110005000618009600         611     479 2013-09-26 16:21:06       37
# 17  6110025000218000384         611     722 2013-09-26 16:24:14       37
# 18  6110005000818089984         611     478 2013-09-26 16:27:13       37
# 19  6110005000918150144         611     486 2013-09-26 16:38:16       37
#
#     estimated_boardings  dwell_time
# 0                    13          27
# 1                     2           6
# 2                     7          16
# 3                     1           3
# 4                     0           1
# 5                     5          12
# 6                    15          31
# 7                    16          34
# 8                     4          10
# 9                     1           3
# 10                   11          24
# 11                    8          17
# 12                    0           2
# 13                    6          14
# 14                   12          26
# 15                   20          41
# 16                   13          27
# 17                    1           3
# 18                    1           4
# 19                    8          17

# %%
type(df.columns)
# Out:
# pandas.core.index.Index

# %%
list(df.columns)
# Out:
# ['trip_id',
#  'service_id',
#  'bus_id',
#  'arrival_time',
#  'stop_id',
#  'estimated_boardings',
#  'dwell_time']

# %%
#make a shifted copy of the data frame to act as the observed predecessor data
df2 = df.shift(1)

# %%
#relabel the column names
new_cols = ["obs_pred_"+x for x in list(df.columns)]
new_cols
df2.columns = new_cols

# %%
df2.head(5)
# Out:
#    obs_pred_trip_id  obs_pred_service_id  obs_pred_bus_id  \
# 0               NaN                  NaN              NaN
# 1      6.110005e+18                  611              475
# 2      6.110005e+18                  611              472
# 3      6.110005e+18                  611              479
# 4      6.110005e+18                  611              486
#
#   obs_pred_arrival_time  obs_pred_stop_id  obs_pred_estimated_boardings  \
# 0                   NaT               NaN                           NaN
# 1   2013-09-26 13:38:36                37                            13
# 2   2013-09-26 13:56:49                37                             2
# 3   2013-09-26 14:01:38                37                             7
# 4   2013-09-26 14:12:08                37                             1
#
#    obs_pred_dwell_time
# 0                  NaN
# 1                   27
# 2                    6
# 3                   16
# 4                    3

# %%
#join the two data frames
pred_df = df.join(df2,how='outer')

# %%
pred_df.head(10)
# Out:
#                trip_id  service_id  bus_id        arrival_time  stop_id  \
# 0  6110005001015150592         611     475 2013-09-26 13:38:36       37
# 1  6110005000415349760         611     472 2013-09-26 13:56:49       37
# 2  6110005000615409664         611     479 2013-09-26 14:01:38       37
# 3  6110005000915550208         611     486 2013-09-26 14:12:08       37
# 4  6110025000316199936         611     734 2013-09-26 14:44:00       37
# 5  6110005000616290304         611     479 2013-09-26 14:45:26       37
# 6  6110005000816350208         611     478 2013-09-26 14:55:48       37
# 7  6110005000916410368         611     486 2013-09-26 15:01:42       37
# 8  6110025000416400384         611     737 2013-09-26 15:06:07       37
# 9  6110005001016489984         611     475 2013-09-26 15:06:13       37
#
#    estimated_boardings  dwell_time  obs_pred_trip_id  obs_pred_service_id  \
# 0                   13          27               NaN                  NaN
# 1                    2           6      6.110005e+18                  611
# 2                    7          16      6.110005e+18                  611
# 3                    1           3      6.110005e+18                  611
# 4                    0           1      6.110005e+18                  611
# 5                    5          12      6.110025e+18                  611
# 6                   15          31      6.110005e+18                  611
# 7                   16          34      6.110005e+18                  611
# 8                    4          10      6.110005e+18                  611
# 9                    1           3      6.110025e+18                  611
#
#    obs_pred_bus_id obs_pred_arrival_time  obs_pred_stop_id  \
# 0              NaN                   NaT               NaN
# 1              475   2013-09-26 13:38:36                37
# 2              472   2013-09-26 13:56:49                37
# 3              479   2013-09-26 14:01:38                37
# 4              486   2013-09-26 14:12:08                37
# 5              734   2013-09-26 14:44:00                37
# 6              479   2013-09-26 14:45:26                37
# 7              478   2013-09-26 14:55:48                37
# 8              486   2013-09-26 15:01:42                37
# 9              737   2013-09-26 15:06:07                37
#
#    obs_pred_estimated_boardings  obs_pred_dwell_time
# 0                           NaN                  NaN
# 1                            13                   27
# 2                             2                    6
# 3                             7                   16
# 4                             1                    3
# 5                             0                    1
# 6                             5                   12
# 7                            15                   31
# 8                            16                   34
# 9                             4                   10

# %%
#remove rows that don't correspond to the observed predecessor

#check if stop_id and obs_pred_stop_id correspond
for i in np.arange(len(pred_df.index)):
    if(pred_df['stop_id'][i] !=pred_df['obs_pred_stop_id'][i]):
        pred_df['obs_pred_stop_id'][i] = float('NaN')
    elif(pred_df['service_id'][i]!= pred_df['obs_pred_service_id'][i]):
        pred_df['obs_pred_service_id'][i] = float('NaN')

# %%
pred_df.head(10)
# Out:
#                trip_id  service_id  bus_id        arrival_time  stop_id  \
# 0  6110005001015150592         611     475 2013-09-26 13:38:36       37
# 1  6110005000415349760         611     472 2013-09-26 13:56:49       37
# 2  6110005000615409664         611     479 2013-09-26 14:01:38       37
# 3  6110005000915550208         611     486 2013-09-26 14:12:08       37
# 4  6110025000316199936         611     734 2013-09-26 14:44:00       37
# 5  6110005000616290304         611     479 2013-09-26 14:45:26       37
# 6  6110005000816350208         611     478 2013-09-26 14:55:48       37
# 7  6110005000916410368         611     486 2013-09-26 15:01:42       37
# 8  6110025000416400384         611     737 2013-09-26 15:06:07       37
# 9  6110005001016489984         611     475 2013-09-26 15:06:13       37
#
#    estimated_boardings  dwell_time  obs_pred_trip_id  obs_pred_service_id  \
# 0                   13          27               NaN                  NaN
# 1                    2           6      6.110005e+18                  611
# 2                    7          16      6.110005e+18                  611
# 3                    1           3      6.110005e+18                  611
# 4                    0           1      6.110005e+18                  611
# 5                    5          12      6.110025e+18                  611
# 6                   15          31      6.110005e+18                  611
# 7                   16          34      6.110005e+18                  611
# 8                    4          10      6.110005e+18                  611
# 9                    1           3      6.110025e+18                  611
#
#    obs_pred_bus_id obs_pred_arrival_time  obs_pred_stop_id  \
# 0              NaN                   NaT               NaN
# 1              475   2013-09-26 13:38:36                37
# 2              472   2013-09-26 13:56:49                37
# 3              479   2013-09-26 14:01:38                37
# 4              486   2013-09-26 14:12:08                37
# 5              734   2013-09-26 14:44:00                37
# 6              479   2013-09-26 14:45:26                37
# 7              478   2013-09-26 14:55:48                37
# 8              486   2013-09-26 15:01:42                37
# 9              737   2013-09-26 15:06:07                37
#
#    obs_pred_estimated_boardings  obs_pred_dwell_time
# 0                           NaN                  NaN
# 1                            13                   27
# 2                             2                    6
# 3                             7                   16
# 4                             1                    3
# 5                             0                    1
# 6                             5                   12
# 7                            15                   31
# 8                            16                   34
# 9                             4                   10

# %%
#pred_df = pred_df.dropna(axis=0)
#pred_df.head(10)

# %%
#pred_df['response']= pd.Series([])

# %%
sched_df = sql.read_frame(sql='SELECT * FROM sched_arrival',con=connection)

# %%
sched_df.head(10)
# Out:
#           arrival_time  route_id  route_id_preceding  sch_headway  \
# 0  2014-02-12 06:49:48        25                 NaN          NaN
# 1  2014-02-12 07:10:48        25                  25         1260
# 2  2014-02-12 07:20:48        25                  25          600
# 3  2014-02-12 07:29:43         5                  25          535
# 4  2014-02-12 07:36:49        25                   5          426
# 5  2014-02-12 07:43:51         5                  25          422
# 6  2014-02-12 07:51:49        25                   5          478
# 7  2014-02-12 07:55:51         5                  25          242
# 8  2014-02-12 08:01:51         5                   5          360
# 9  2014-02-12 08:06:49        25                   5          298
#
#    sch_headway_own  service_id  stop_id  stop_seq              trip_id
# 0              NaN         611       46         6  6110025000106439680
# 1             1260         611       46         6  6110025000207049728
# 2              600         611       46         6  6110025000507150336
# 3              NaN         611       46         2  6110005000107289600
# 4              961         611       46         6  6110025000607300608
# 5              848         611       46         2  6110005000307430400
# 6              900         611       46         6  6110025000707449856
# 7              720         611       46         2  6110005000607550464
# 8              360         611       46         2  6110005000808009728
# 9              900         611       46         6  6110025000208000000

# %%
#convert sched_arrival_time to a date time object
sched_df['sched_arrival_time']= pd.to_datetime(df['arrival_time'])
type(sched_df['sched_arrival_time'][1])
# Out:
# pandas.tslib.Timestamp
